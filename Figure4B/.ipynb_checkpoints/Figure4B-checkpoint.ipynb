# %%
# %cd '/qbio/nest/prom317/tutorial/transcriptomeAlignment/'
import numpy as np
import pandas as pd
import os

homeDirectory = "/qbio/nest/prom317/tutorial/transcriptomeAlignment/"
directoryList = os.listdir(homeDirectory)
print(directoryList)
del directoryList[5]
dataList=[]

def alignAnalyze(samFileName):
    dataColList = list()
    print(samFileName)
    dataColDF = pd.read_csv(samFileName+"/Aligned_results.sam", sep = '\t', header = None)
    print(dataColDF.shape)
    dataColDF.iloc[:,2] = dataColDF.iloc[:,2].map(lambda p : p.split('|')[0])

    return dataColDF.loc[dataColDF.iloc[:,1] != 4].iloc[:,2].value_counts()

dataList.append(alignAnalyze(directoryList[0]))
# Out:
# /qbio/nest/prom317/tutorial/transcriptomeAlignment
# ['RNAseq_siLin28a', 'RPF_siLuc', 'RPF_siLin28a', 'CLIP_35L33G', 'RNAseq_siLuc', '.ipynb_checkpoints', 'RNAseq_untreated']
# RNAseq_siLin28a
# (49940316, 15)

# %%
frame = {'RNAseq_untreated': dataList[5], 'RNAseq_siLuc': dataList[4], 'RNAseq_siLin28a': dataList[0], 'RPF_siLuc': dataList[1], 'RPF_siLin28a': dataList[2], 'CLIP': dataList[3]}
wholeDF = pd.DataFrame(frame)
wholeDF.head()
# Out:
#                        RNAseq_untreated  RNAseq_siLuc  RNAseq_siLin28a  \
# ENSMUST00000000001.5             2025.0        1845.0           1513.0
# ENSMUST00000000003.14               1.0           7.0              NaN
# ENSMUST00000000010.9               10.0           NaN              4.0
# ENSMUST00000000028.14            1192.0         939.0           1029.0
# ENSMUST00000000033.12              15.0           1.0              7.0
#
#                        RPF_siLuc  RPF_siLin28a    CLIP
# ENSMUST00000000001.5       681.0         363.0  2622.0
# ENSMUST00000000003.14        NaN           NaN    52.0
# ENSMUST00000000010.9         5.0           7.0    95.0
# ENSMUST00000000028.14      402.0         223.0   697.0
# ENSMUST00000000033.12       10.0          14.0   157.0

# %%
dataList.append(alignAnalyze(directoryList[1]))

# %%
dataList.append(alignAnalyze(directoryList[2]))

# %%
dataList.append(alignAnalyze(directoryList[3]))

# %%
dataList.append(alignAnalyze(directoryList[4]))
# Out:
# RNAseq_siLuc
# (38725543, 15)

# %%
dataList.append(alignAnalyze(directoryList[5]))
# Out:
# RNAseq_untreated
# (47690315, 15)

# %%
wholeDF=wholeDF.fillna(1)
wholeDF_cut = wholeDF.loc[wholeDF["CLIP"] > 250]
wholeDF_cut = wholeDF_cut.loc[wholeDF_cut["RPF_siLin28a"]>250]
wholeDF_cut = wholeDF_cut.loc[wholeDF_cut["RNAseq_siLuc"]>250]
wholeDF_cut.head()
# Out:
#                       RNAseq_untreated  RNAseq_siLuc  RNAseq_siLin28a  \
# ENSMUST00000000001.5            2025.0        1845.0           1513.0
# ENSMUST00000000090.8            2937.0        1591.0           2249.0
# ENSMUST00000000122.7             388.0         438.0           1276.0
# ENSMUST00000000137.8            8087.0        6431.0           7064.0
# ENSMUST00000000175.6            1921.0         914.0           1394.0
#
#                       RPF_siLuc  RPF_siLin28a     CLIP
# ENSMUST00000000001.5      681.0         363.0   2622.0
# ENSMUST00000000090.8     4037.0        4221.0   3559.0
# ENSMUST00000000122.7     1126.0        2064.0    641.0
# ENSMUST00000000137.8     5871.0        4277.0  11233.0
# ENSMUST00000000175.6     1618.0        1498.0   1496.0

# %%
wholeDF_cut['enrichment']=np.log2(wholeDF_cut['CLIP']/wholeDF_cut['RNAseq_untreated'])
wholeDF_cut['density_change'] = np.log2((wholeDF_cut['RPF_siLin28a']*wholeDF_cut['RNAseq_siLuc'])/(wholeDF_cut['RPF_siLuc']*wholeDF_cut['RNAseq_siLin28a']))
wholeDF_cut.head()
# Out:
#                       RNAseq_untreated  RNAseq_siLuc  RNAseq_siLin28a  \
# ENSMUST00000000001.5            2025.0        1845.0           1513.0
# ENSMUST00000000090.8            2937.0        1591.0           2249.0
# ENSMUST00000000122.7             388.0         438.0           1276.0
# ENSMUST00000000137.8            8087.0        6431.0           7064.0
# ENSMUST00000000175.6            1921.0         914.0           1394.0
#
#                       RPF_siLuc  RPF_siLin28a     CLIP  enrichment  \
# ENSMUST00000000001.5      681.0         363.0   2622.0    0.372746
# ENSMUST00000000090.8     4037.0        4221.0   3559.0    0.277129
# ENSMUST00000000122.7     1126.0        2064.0    641.0    0.724268
# ENSMUST00000000137.8     5871.0        4277.0  11233.0    0.474067
# ENSMUST00000000175.6     1618.0        1498.0   1496.0   -0.360747
#
#                       density_change
# ENSMUST00000000001.5       -0.621476
# ENSMUST00000000090.8       -0.435049
# ENSMUST00000000122.7       -0.668389
# ENSMUST00000000137.8       -0.592449
# ENSMUST00000000175.6       -0.720138

# %%
import matplotlib.pyplot as plt
scatter = plt.scatter(x=wholeDF_cut['enrichment'], y=wholeDF_cut['density_change'], c = 'black', alpha = 0.5, s =1)
plt.title('CLIP and ribosome footprinting upon Lin28a knockdown')
plt.xlabel('LIN28A CLIP enrichment (log2)')
plt.ylabel('Ribosome density change \nupon Lin28a knockdown (log2)')
plt.xlim(-6,4)
plt.ylim(-2, 2)
plt.yticks([-2,-1,0,1,2])
plt.rcParams['figure.figsize']=(5,5)
plt.show()

corr = np.corrcoef(wholeDF_cut['enrichment'], wholeDF_cut['density_change'])
print(corr)
# Out:
# [[1.        0.5141057]
#  [0.5141057 1.       ]]

# %%
uniport = pd.read_csv('/qbio/nest/prom317/tutorial/uniprot-Mus+musculus.tab', sep = '\t')
for idx, row in uniport.iterrows():
    if isinstance(row['Ensembl transcript'], str):
        for ensem in row['Ensembl transcript'].split(';'):
            for dfIdx in wholeDF_cut.index:
                if ensem[0:18] == dfIdx[0:18]:
                    wholeDF_cut.loc[dfIdx,"Gene Ontology"]=row['Gene ontology (cellular component)']

wholeDF_cut.head()
# Out:
#                       RNAseq_untreated  RNAseq_siLuc  RNAseq_siLin28a  \
# ENSMUST00000000001.5            2025.0        1845.0           1513.0
# ENSMUST00000000090.8            2937.0        1591.0           2249.0
# ENSMUST00000000122.7             388.0         438.0           1276.0
# ENSMUST00000000137.8            8087.0        6431.0           7064.0
# ENSMUST00000000175.6            1921.0         914.0           1394.0
#
#                       RPF_siLuc  RPF_siLin28a     CLIP  enrichment  \
# ENSMUST00000000001.5      681.0         363.0   2622.0    0.372746
# ENSMUST00000000090.8     4037.0        4221.0   3559.0    0.277129
# ENSMUST00000000122.7     1126.0        2064.0    641.0    0.724268
# ENSMUST00000000137.8     5871.0        4277.0  11233.0    0.474067
# ENSMUST00000000175.6     1618.0        1498.0   1496.0   -0.360747
#
#                       density_change  \
# ENSMUST00000000001.5       -0.621476
# ENSMUST00000000090.8       -0.435049
# ENSMUST00000000122.7       -0.668389
# ENSMUST00000000137.8       -0.592449
# ENSMUST00000000175.6       -0.720138
#
#                                                           Gene Ontology
# ENSMUST00000000001.5  centrosome [GO:0005813]; cytoplasm [GO:0005737...
# ENSMUST00000000090.8  mitochondrial inner membrane [GO:0005743]; mit...
# ENSMUST00000000122.7  cell-cell junction [GO:0005911]; cell surface ...
# ENSMUST00000000137.8  actin cap [GO:0030478]; Arp2/3 protein complex...
# ENSMUST00000000175.6  integral component of membrane [GO:0016021]; m...

# %%
wholeDF_cut_dropna = wholeDF_cut.dropna(axis = 0)
wholeDF_cut_dropna.head()
# Out:
#                       RNAseq_untreated  RNAseq_siLuc  RNAseq_siLin28a  \
# ENSMUST00000000001.5            2025.0        1845.0           1513.0
# ENSMUST00000000090.8            2937.0        1591.0           2249.0
# ENSMUST00000000122.7             388.0         438.0           1276.0
# ENSMUST00000000137.8            8087.0        6431.0           7064.0
# ENSMUST00000000175.6            1921.0         914.0           1394.0
#
#                       RPF_siLuc  RPF_siLin28a     CLIP  enrichment  \
# ENSMUST00000000001.5      681.0         363.0   2622.0    0.372746
# ENSMUST00000000090.8     4037.0        4221.0   3559.0    0.277129
# ENSMUST00000000122.7     1126.0        2064.0    641.0    0.724268
# ENSMUST00000000137.8     5871.0        4277.0  11233.0    0.474067
# ENSMUST00000000175.6     1618.0        1498.0   1496.0   -0.360747
#
#                       density_change  \
# ENSMUST00000000001.5       -0.621476
# ENSMUST00000000090.8       -0.435049
# ENSMUST00000000122.7       -0.668389
# ENSMUST00000000137.8       -0.592449
# ENSMUST00000000175.6       -0.720138
#
#                                                           Gene Ontology
# ENSMUST00000000001.5  centrosome [GO:0005813]; cytoplasm [GO:0005737...
# ENSMUST00000000090.8  mitochondrial inner membrane [GO:0005743]; mit...
# ENSMUST00000000122.7  cell-cell junction [GO:0005911]; cell surface ...
# ENSMUST00000000137.8  actin cap [GO:0030478]; Arp2/3 protein complex...
# ENSMUST00000000175.6  integral component of membrane [GO:0016021]; m...

# %%
n = "nucle"
i = "integ"
c = "cyto"
for idx, row in wholeDF_cut_dropna.iterrows():
    if n in row['Gene Ontology']:
        wholeDF_cut_dropna.loc[idx, "Gene Ontology"] = "nucleus"
    elif i in row['Gene Ontology']:
        wholeDF_cut_dropna.loc[idx, "Gene Ontology"] = "integral membrane"
    elif c in row["Gene Ontology"]:
        wholeDF_cut_dropna.loc[idx, "Gene Ontology"] = "cytoplasm"
    elif "mito" in row["Gene Ontology"]:
        wholeDF_cut_dropna.loc[idx, "Gene Ontology"] = "integral membrane"
    elif "endo" in row["Gene Ontology"]:
        wholeDF_cut_dropna.loc[idx, "Gene Ontology"] = "integral membrane"
    elif "ribo" in row["Gene Ontology"]:
        wholeDF_cut_dropna.loc[idx, "Gene Ontology"] = "cytoplasm"
    else:
        wholeDF_cut_dropna.loc[idx, "Gene Ontology"] = np.nan
# Out:
# /blaze/prom317/conda/envs/lab/lib/python3.7/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
groups = wholeDF_cut_dropna.groupby("Gene Ontology")
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group['enrichment'], group['density_change'], marker = 'o', linestyle = '', label = name, alpha = 1, markersize = 1)
ax.legend(loc = "upper left")
plt.title('CLIP and ribosome footprinting upon Lin28a knockdown')
plt.xlabel('LIN28A CLIP enrichment (log2)')
plt.ylabel('Ribosome density change upon Lin28a knockdown (log2)')
plt.xlim(-6,4)
plt.ylim(-2, 2)
plt.yticks([-2,-1,0,1,2])
plt.show()
